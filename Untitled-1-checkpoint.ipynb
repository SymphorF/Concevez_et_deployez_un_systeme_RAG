# %%
import faiss
print("FAISS version :", faiss.__version__)

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.0.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Downloading langchain_core-1.0.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.0 (from langchain)
#   Downloading langgraph-1.0.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.10.6)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading langsmith-0.4.38-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.2)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.12.2)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading ormsgpack-1.11.0-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.11.0)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.3)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (4.8.0)
# Requirement already satisfied: certifi in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.0.7)
# Requirement already satisfied: idna in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.3.1)
# Downloading langchain-1.0.2-py3-none-any.whl (107 kB)
# Downloading langchain_core-1.0.1-py3-none-any.whl (467 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.1-py3-none-any.whl (155 kB)
# Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.38-py3-none-any.whl (397 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading ormsgpack-1.11.0-cp312-cp312-win_amd64.whl (112 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, tenacity, ormsgpack, jsonpointer, requests-toolbelt, jsonpatch, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ----------------------------------------  0/14 [zstandard]
#    -- -------------------------------------  1/14 [xxhash]
#    ----- ----------------------------------  2/14 [tenacity]
#    ----- ----------------------------------  2/14 [tenacity]
#    ----- ----------------------------------  2/14 [tenacity]
#    -------- -------------------------------  3/14 [ormsgpack]
#    ----------- ----------------------------  4/14 [jsonpointer]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    -------------- -------------------------  5/14 [requests-toolbelt]
#    ----------------- ----------------------  6/14 [jsonpatch]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    -------------------- -------------------  7/14 [langsmith]
#    ---------------------- -----------------  8/14 [langgraph-sdk]
#    ---------------------- -----------------  8/14 [langgraph-sdk]
#    ---------------------- -----------------  8/14 [langgraph-sdk]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ------------------------- --------------  9/14 [langchain-core]
#    ---------------------------- ----------- 10/14 [langgraph-checkpoint]
#    ---------------------------- ----------- 10/14 [langgraph-checkpoint]
#    ---------------------------- ----------- 10/14 [langgraph-checkpoint]
#    ---------------------------- ----------- 10/14 [langgraph-checkpoint]
#    ------------------------------- -------- 11/14 [langgraph-prebuilt]
#    ------------------------------- -------- 11/14 [langgraph-prebuilt]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ---------------------------------- ----- 12/14 [langgraph]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ------------------------------------- -- 13/14 [langchain]
#    ---------------------------------------- 14/14 [langchain]
#
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.2 langchain-core-1.0.1 langgraph-1.0.1 langgraph-checkpoint-3.0.0 langgraph-prebuilt-1.0.1 langgraph-sdk-0.2.9 langsmith-0.4.38 ormsgpack-1.11.0 requests-toolbelt-1.0.0 tenacity-9.1.2 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.vectorstores import FAISS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain_community'
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from mistralai import Mistral
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from mistralai import Mistral
#
# ModuleNotFoundError: No module named 'mistralai'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\PC\OneDrive\Documents\OPENCLASSROOMS - FORMATION\00 - Data Scientist Machine Learning\Projet 9\Exercice\Cours sur les Systèmes RAG\.venv\Scripts\python.exe

# %%
import faiss
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import faiss
#
# ModuleNotFoundError: No module named 'faiss'

# %%
from langchain.vectorstores import FAISS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from langchain.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain.vectorstores'

# %%
from langchain.embeddings import HuggingFaceEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain.embeddings import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'langchain.embeddings' (c:\Users\PC\OneDrive\Documents\OPENCLASSROOMS - FORMATION\00 - Data Scientist Machine Learning\Projet 9\Exercice\.venv\Lib\site-packages\langchain\embeddings\__init__.py)

# %%
from mistralai.client import MistralClient
